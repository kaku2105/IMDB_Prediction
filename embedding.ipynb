# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
##SEntences
sent=['The Glass of Milk', 'The Cup of Tea', 'I am a Good Boy', 'I am a Good Developer', 'The vedios are good']

# %%
sent
# Out:
# ['The Glass of Milk',
#  'The Cup of Tea',
#  'I am a Good Boy',
#  'I am a Good Developer',
#  'The vedios are good']

# %%
##Define the vocabulary size 
voc_size=10000

# %%
##ONe Hot Representation
one_hot_rep=[one_hot(words, voc_size)for words in sent]
one_hot_rep
# Out:
# [[4004, 5496, 1568, 8953],
#  [4004, 6948, 1568, 9504],
#  [7645, 2560, 7317, 1138, 2643],
#  [7645, 2560, 7317, 1138, 7493],
#  [4004, 9998, 3241, 1138]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=10
embedded_docs=pad_sequences(one_hot_rep,padding='pre', maxlen=sent_length)
embedded_docs
# Out:
# array([[   0,    0,    0,    0,    0,    0, 4004, 5496, 1568, 8953],
#        [   0,    0,    0,    0,    0,    0, 4004, 6948, 1568, 9504],
#        [   0,    0,    0,    0,    0, 7645, 2560, 7317, 1138, 2643],
#        [   0,    0,    0,    0,    0, 7645, 2560, 7317, 1138, 7493],
#        [   0,    0,    0,    0,    0,    0, 4004, 9998, 3241, 1138]])

# %%
##Feature Representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam', 'mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 10, 10)            100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 217ms/step
# array([[[ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [-0.03749279, -0.02998421, -0.03318446, -0.03412835,
#          -0.03691454, -0.02314382,  0.04764053,  0.04166796,
#          -0.02784965, -0.02530864],
#         [-0.00147132,  0.00592453,  0.04884401,  0.02678218,
#          -0.04738382,  0.02058424,  0.04788369,  0.0397971 ,
#          -0.01005251,  0.0315336 ],
#         [ 0.04399022, -0.01883606,  0.02819624,  0.0006084 ,
#          -0.02099352,  0.03486996,  0.02746716,  0.03941638,
#          -0.00649492, -0.01132727],
#         [ 0.0207685 , -0.01787351, -0.02925452,  0.02575219,
#           0.0071073 ,  0.02017168, -0.00156858,  0.01142924,
#           0.04953188, -0.01540086]],
#
#        [[ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [-0.03749279, -0.02998421, -0.03318446, -0.03412835,
#          -0.03691454, -0.02314382,  0.04764053,  0.04166796,
#          -0.02784965, -0.02530864],
#         [ 0.00723862, -0.01782922, -0.0016832 , -0.0114603 ,
#          -0.01075432, -0.01204499,  0.04509982,  0.0107917 ,
#          -0.04650258, -0.00796806],
#         [ 0.04399022, -0.01883606,  0.02819624,  0.0006084 ,
#          -0.02099352,  0.03486996,  0.02746716,  0.03941638,
#          -0.00649492, -0.01132727],
#         [-0.04193361,  0.01657139,  0.03413964,  0.0487797 ,
#           0.02433423, -0.01912848, -0.04846975, -0.04872366,
#          -0.02624562, -0.00284064]],
#
#        [[ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.0042928 , -0.01728546, -0.03085141, -0.049327  ,
#           0.00174173,  0.00907754,  0.04530833, -0.00439919,
#          -0.00443915, -0.03480041],
#         [-0.00100142, -0.01972853,  0.04475388,  0.01604608,
#          -0.02830454,  0.00186952,  0.01947601,  0.04885462,
#           0.03787848,  0.01025175],
#         [-0.01777007, -0.02626172, -0.02722384, -0.00595075,
#           0.04998586, -0.00776631,  0.03949926,  0.03576053,
#          -0.01656476,  0.01326444],
#         [-0.04715033,  0.02685926,  0.02444899,  0.00166535,
#           0.02216187, -0.00147527, -0.00148254,  0.04532662,
#           0.04345817, -0.02861066],
#         [ 0.03907892,  0.04430068,  0.02161268, -0.02495102,
#           0.01069088,  0.04061511, -0.02545717,  0.04092934,
#           0.04449471,  0.00226348]],
#
#        [[ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.0042928 , -0.01728546, -0.03085141, -0.049327  ,
#           0.00174173,  0.00907754,  0.04530833, -0.00439919,
#          -0.00443915, -0.03480041],
#         [-0.00100142, -0.01972853,  0.04475388,  0.01604608,
#          -0.02830454,  0.00186952,  0.01947601,  0.04885462,
#           0.03787848,  0.01025175],
#         [-0.01777007, -0.02626172, -0.02722384, -0.00595075,
#           0.04998586, -0.00776631,  0.03949926,  0.03576053,
#          -0.01656476,  0.01326444],
#         [-0.04715033,  0.02685926,  0.02444899,  0.00166535,
#           0.02216187, -0.00147527, -0.00148254,  0.04532662,
#           0.04345817, -0.02861066],
#         [-0.04702147,  0.02151599, -0.00891757, -0.01399601,
#           0.02511458,  0.01328561, -0.04742249, -0.03472919,
#          -0.04321131,  0.03303999]],
#
#        [[ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [ 0.00241715,  0.0492346 ,  0.04587177,  0.04259238,
#           0.03714695, -0.00380297, -0.00076299, -0.00719953,
#           0.02271165,  0.01031094],
#         [-0.03749279, -0.02998421, -0.03318446, -0.03412835,
#          -0.03691454, -0.02314382,  0.04764053,  0.04166796,
#          -0.02784965, -0.02530864],
#         [ 0.0150831 ,  0.03765667,  0.01872058,  0.0031314 ,
#          -0.02638561,  0.01141349,  0.01177516,  0.03529933,
#          -0.0158575 , -0.03598505],
#         [ 0.02745218, -0.04826803,  0.00519134,  0.0167805 ,
#          -0.0310186 ,  0.01138276,  0.00576215,  0.02478571,
#           0.01208872,  0.00314125],
#         [-0.04715033,  0.02685926,  0.02444899,  0.00166535,
#           0.02216187, -0.00147527, -0.00148254,  0.04532662,
#           0.04345817, -0.02861066]]], dtype=float32)

# %%
# Create an instance of EarlyStopping Callback

from tensorflow.keras.callbacks import EarlyStopping
earlystopping=EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
earlystopping
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Create an instance of EarlyStopping Callback
# ----> 3 from tensorflow.keras.callbacks import EarlyStopping
#       4 earlystopping=EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
#       5 earlystopping
#
# ModuleNotFoundError: No module named 'tensorflow'
